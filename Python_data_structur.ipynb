# %% [markdown]
# <a href="https://colab.research.google.com/github/muhamadalfarisy98/odooCode/blob/main/Python_data_structur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#built-in data structures
#1. strings
#2. List
#3. Dict
#4. Tuple
#5. Set

# %%
#other prominent 

"""
1. Stacks
2. Queues
3. Trees
4. Linked List
"""
# Out:
# '\n1. Stacks\n2. Queues\n3. Trees\n4. Linked List\n'

# %%
x=[1,2,3,4,5]

# %%
x.pop()
# Out:
# 5

# %%
x.remove(2)

# %%
x
# Out:
# [1, 3, 4]

# %% [markdown]
# **String Functions**

# %%
x="This is some text"
print(x.count("s")) #menghitung banyak ch s
# Out:
# 3

# %%
x.replace("some text","awesome")
# Out:
# 'This is awesome'

# %% [markdown]
# **List Function**

# %%
x=[2,4,6]

# %%
x.append(8)

# %%
x.remove(4)

# %%
x
# Out:
# [2, 6, 8]

# %%
x.insert(0,8)
x
# Out:
# [8, 2, 6, 8]

# %%
x.count(8)
x
# Out:
# [8, 2, 6, 8]

# %%
x.reverse()
x
# Out:
# [8, 6, 2, 8]

# %%
x.sort()
x
# Out:
# [2, 6, 8, 8]

# %%
min(x)
# Out:
# 2

# %% [markdown]
# **List Comprehensions**
#
# useful way of quickly creating list whose contents obey a rule

# %%
cubes=[i**3 for i in range(5)]
print(cubes)
# Out:
# [0, 1, 8, 27, 64]

# %%
cube=', '.join(map(str,cubes))
cube
# Out:
# '0, 1, 8, 27, 64'

# %%
evens=[i**2 for i in range(10) if i**2%2==0]
evens
# Out:
# [0, 4, 16, 36, 64]

# %%
text = input().split()
len_text=len(text)
join_text=''.join(text)
count=0
for i in join_text:
    count+=1

cal=count/len_text
print("%.1f" %cal)
# Out:
# 'this is some text'
# 4.0

# %% [markdown]
# **Dict**

# %%
ages={
    "dave":24,
    "mary":42,
    "jon":58
}
print(ages["dave"])
# Out:
# 24

# %%
"""
You can use strings, integers, booleans, and any other immutable type as dictionary keys.
This means that you cannot use lists or dictionaries as keys:
"""
# Out:
# '\nYou can use strings, integers, booleans, and any other immutable type as dictionary keys.\nThis means that you cannot use lists or dictionaries as keys:\n'

# %%
print("dave" in ages)
# Out:
# True

# %%
print(24 in ages)
# Out:
# False

# %%
# useful dict function>> get()
pairs={
    1:"apple",
    "orange":[2,3,4],
    True:False,
    12:"True",
}

# %%
print(pairs.get(True))
# Out:
# False

# %%
print(pairs.get("apple","not found"))
# Out:
# not found

# %%
print(pairs.get(12))
# Out:
# True

# %% [markdown]
# **Tuples**
#
# similar to list but immutable, an advantage of tuples over list is that they can be used as keys for dict (because immut)

# %%
words=("spam","eggs","sausage")
words[0]
# Out:
# 'spam'

# %%
words[1]="cheese"
words
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-dee57ff5f45e> in <module>()
# ----> 1 words[1]="cheese"
#       2 words
#
# TypeError: 'tuple' object does not support item assignment

# %%
dict={
    ("david",42):"red",
    ("bob",24):"green"
}

# %%
print(dict["bob",24])
# Out:
# green

# %%
#tuple unpacking
numbers=(1,2,3,)
a,b,c=numbers
print(c)
# Out:
# 3

# %%
a,b,*c,d=[1,2,3,4,5,6]
print(c)
# Out:
# [3, 4, 5]

# %%
print(d)
# Out:
# 6

# %% [markdown]
# **Sets**
#
# a collection of unordered items that are unique

# %%
num_set={1,2,3,4}
if 4 in num_set:
  print(False)
# Out:
# False

# %%
num_set.add(-7)

# %%
num_set
# Out:
# {-7, 1, 2, 3, 4}

# %%
num_set.remove(1)
num_set
# Out:
# {-7, 2, 3, 4}

# %%
first={1,2,3,4,5}
second={4,5,6,7}

# %%
#string union
print(first | second)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#string intersection
print(first & second)
# Out:
# {4, 5}

# %%
#different operator in the first set
print(first- second)
# Out:
# {1, 2, 3}

# %%
# get in either but not both
print(first^second)
# Out:
# {1, 2, 3, 6, 7}

# %%
print(first & second)
# Out:
# {4, 5}

# %% [markdown]
# ![best p.png](data:image/png;base64,...)

# %%
data = {
    "100-90": 25, 
    "42-01": 48, 
    "55-09": 12, 
    "128-64": 71, 
    "002-22": 18, 
    "321-54": 19, 
    "097-32": 33,
}

count=0
for j in data.values():
  count+=j
print(count)
# Out:
# 226

# %% [markdown]
# **User Defined data struct**

# %% [markdown]
# ![stack.png](data:image/png;base64,...)

# %%
#stack in python
class stack():
  def __init__(self):
    self.items=[]

  def is_empty(self):
    return self.items==[]

  def push(self,item):
    return self.items.insert(0,item)
  
  def pop(self,item):
    return self.items.pop(0)

  def print_stack(self):
    print(self.items)

# %%
op=stack()

# %%
op.push(3)

# %%
op

# %%
op.print_stack()
# Out:
# [3]

# %%
for i in range(4,10):
  op.push(i)

# %%
op.print_stack()
# Out:
# [9, 8, 7, 6, 5, 4, 3]

# %%
op.is_empty()
# Out:
# False

# %% [markdown]
# ![q.png](data:image/png;base64,...)

# %%
class queue(stack):
  def __init__(self):
        stack.__init__(self,)

  def enqueue(self,item):
    return self.items.insert(0,item)

  def dequeue(self):
    return self.items.pop()

# %%
op2=queue()

# %%
op2.enqueue(10)

# %%
op2

# %%
op2.print_stack()
# Out:
# [10]

# %%
for k in range(0,4):
  op2.enqueue(k)

# %%
op2.print_stack()
op2.dequeue()
# Out:
# [3, 2, 1, 0, 10]
# 10

# %% [markdown]
# ![ll.png](data:image/png;base64,...)

# %%
class Node():
  def __init__(self,data,next):
    self.data=data
    self.next=next

# %%
class LinkedList():
  def __init__(self):
    self.head=None

  def add_at_front(self,data):
    self.head=Node(data,self.head)

  def add_at_end(self,data):
    if not self.head:
      self.head=Node(data,None)
      return
    
    curr=self.head
    while curr.next:
      curr=curr.next
    curr.next=Node(data,None)

  def get_last_node(self):
    n=self.head
    while(n.next!=None):
      n=n.next
    return n.data

  def is_empty(self):
    return self.head==None
  
  def print_list(self):
    n=self.head
    while n!=None:
      print(n.data,end =" => ")
      n=n.next
    print()

# %%
s=LinkedList()
s.add_at_front(5)

# %%
s.print_list()
# Out:
# 5 =>

# %%
s.add_at_end(8)

# %%
s.print_list()
# Out:
# 5 => 8 =>

# %%
s.add_at_front(9)

# %%
s.print_list()
# Out:
# 9 => 5 => 8 =>

# %%
s.get_last_node()
# Out:
# 8

# %%
p=LinkedList().head

# %%
s=s.head
while s!=None:
  print(s.data)
  s=s.next
# Out:
# 9
# 5
# 8

# %%
ot

# %% [markdown]
# ![g.png](data:image/png;base64,...)

# %%
q= None
if not q :
  print(False)
# Out:
# False

# %%
def bracket(expr):
  stack = []
  for paren in expr:
      if paren == '(':
          stack.append(paren)
      else:
          try:
              stack.pop()
          except IndexError:  # too many closing parens
              return False
  return len(stack) == 0  # false if too many opening parens

# %%
print(bracket('(a( ) eee)' ))
# Out:
# False

# %%
''
# Out:
# ''

# %%
# Code by: Rajid Al Asad
 
# line 26-29
class Stack:
    def __init__(self):
        self.items = []  
  
    def is_empty(self):
        return self.items == []
  
    def push(self, item):
        self.items.insert(0, item)
    
    def pop(self):
        return self.items.pop(0)

    # re-return self define variable in init method
    def stack(self):
        return self.items

def balanced(expression):
    s = Stack()
    for i in expression:
        if i == '(':
            s.push(i)
        if i == ')':
            if '(' in s.stack():
                s.pop()
            else:
                return False

    if not s.stack():
        return True
    else:
        return False
        
print(balanced(input()))
# Out:
# (a( ) eee)
# True

# %%
(a( ) eee) )
